# %% [markdown]
# #
# <span style="color:darkolivegreen; font-size:50px; text-align:center">강남 3구는 안전한가?</span>
# <img src = "data/map_of_seoul.jpeg"/>
# #

# %%
import numpy as np
import pandas as pd
import googlemaps
import os
import matplotlib.pyplot as plt

# %%
geocode_of_stations = pd.read_excel('geocode_of_stations.xls')
geocode_of_stations.drop(['partial_match','place_id','types', 'address_components'] , axis = 1)
# Out:
#                          formatted_address  \
# 0                대한민국 서울특별시 중구 을지로동 수표로 27
# 1        대한민국 서울특별시 종로구 종로1.2.3.4가동 율곡로 46
# 2            대한민국 서울특별시 중구 남대문로5가 한강대로 410
# 3              대한민국 서울특별시 서대문구 미근동 통일로 113
# 4   대한민국 서울특별시 종로구 종로1.2.3.4가동 창경궁로 112-16
# 5                  대한민국 서울특별시 용산구 원효로1가 25
# 6                 대한민국 서울특별시 성북구 삼선동5가 301
# 7          대한민국 서울특별시 동대문구 청량리동 약령시로21길 29
# 8                 대한민국 서울특별시 마포구 아현동 618-1
# 9               대한민국 서울특별시 영등포구 당산동3가 2-11
# 10            대한민국 서울특별시 성동구 행당1동 왕십리광장로 9
# 11                  대한민국 서울특별시 동작구 노량진동 72
# 12             대한민국 서울특별시 광진구 구의1동 자양로 167
# 13              대한민국 서울특별시 은평구 대조동 통일로 757
# 14               대한민국 서울특별시 강북구 번1동 415-15
# 15                  대한민국 서울특별시 관악구 신림동 544
# 16                대한민국 서울특별시 중랑구 묵2동 249-2
# 17                  대한민국 서울특별시 강남구 대치동 998
# 18                      대한민국 서울특별시 관악구 봉천동
# 19               대한민국 서울특별시 양천구 신월동 화곡로 73
# 20              대한민국 서울특별시 강동구 성내1동 성내로 57
# ...

# %%
geocode_of_stations.geometry
# Out:
# 0     {'location': {'lat': 37.5636465, 'lng': 126.98...
# 1     {'location': {'lat': 37.5755578, 'lng': 126.98...
# 2     {'location': {'lat': 37.5547584, 'lng': 126.97...
# 3     {'location': {'lat': 37.5647848, 'lng': 126.96...
# 4     {'location': {'lat': 37.5718401, 'lng': 126.99...
# 5     {'location': {'lat': 37.538649, 'lng': 126.966...
# 6     {'location': {'lat': 37.5897271, 'lng': 127.01...
# 7     {'location': {'lat': 37.58506149999999, 'lng':...
# 8     {'location': {'lat': 37.550814, 'lng': 126.954...
# 9     {'location': {'lat': 37.5257884, 'lng': 126.90...
# 10    {'location': {'lat': 37.5617309, 'lng': 127.03...
# 11    {'location': {'lat': 37.5130685, 'lng': 126.94...
# 12    {'location': {'lat': 37.542873, 'lng': 127.083...
# 13    {'location': {'lat': 37.6128611, 'lng': 126.92...
# 14    {'location': {'lat': 37.6373881, 'lng': 127.02...
# 15    {'location': {'lat': 37.4814051, 'lng': 126.90...
# 16    {'location': {'lat': 37.6056429, 'lng': 127.07...
# ...

# %%
geocode_of_stations.geometry.head()[0]
# Out:
# "{'location': {'lat': 37.5636465, 'lng': 126.9895796}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 37.56499548029149, 'lng': 126.9909285802915}, 'southwest': {'lat': 37.56229751970849, 'lng': 126.9882306197085}}}"

# %%
crime_in_Seoul = pd.read_csv("/Users/quan/some_ipynbs/data/02. crime_in_Seoul.csv" , encoding = "EUC-KR", thousands = ',')
crime_in_Seoul['구역'] = geocode_of_stations['formatted_address'].str.split().str[2]
crime_in_Seoul.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#      구역
# 0    중구
# 1   종로구
# 2    중구
# 3  서대문구
# 4   종로구

# %%
# gmaps = googlemaps.Client(key = 'AIzaSyAVReYXU1OpjZk8NqQ7P93pXBni5jXaXV0')
# gmaps.geocode('서울도봉경찰서', language = 'ko')

# %%
pd.pivot_table(crime_in_Seoul,index = ['구역','관서명'],aggfunc = np.sum ).head()
# Out:
#          강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생
# 구역  관서명
# 강남구 강남서    225    300     12     15      3      3    984   2411   2146   2465
#     수서서    124    149      6      6      7     10    666   1439   1559   1819
# 강동구 강동서    123    156      8      6      3      4    789   2366   2248   2712
# 강북구 강북서    126    153     13     14      8      7    618   1434   2348   2649
# 관악구 관악서    221    320     14     12      8      9    827   2706   2642   3298

# %%
crime_anal = pd.pivot_table(crime_in_Seoul,index = ['구역'],aggfunc = np.sum )
crime_anal.head()
# Out:
#      강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생
# 구역
# 강남구    349    449     18     21     10     13   1650   3850   3705   4284
# 강동구    123    156      8      6      3      4    789   2366   2248   2712
# 강북구    126    153     13     14      8      7    618   1434   2348   2649
# 관악구    343    471     20     18     12     12   1715   4273   4418   5352
# 광진구    220    240     26     14      4      4   1277   3026   2180   2625

# %%
crime_anal['강간검거율'] = crime_anal['강간 검거']/crime_anal['강간 발생']*100
crime_anal['강도검거율'] = crime_anal['강도 검거']/crime_anal['강도 발생']*100
crime_anal['살인검거율'] = crime_anal['살인 검거']/crime_anal['살인 발생']*100
crime_anal['절도검거율'] = crime_anal['절도 검거']/crime_anal['절도 발생']*100
crime_anal['폭력검거율'] = crime_anal['폭력 검거']/crime_anal['폭력 발생']*100

# %%
crime_anal.head()
# Out:
#      강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생  \
# 구역
# 강남구    349    449     18     21     10     13   1650   3850   3705   4284
# 강동구    123    156      8      6      3      4    789   2366   2248   2712
# 강북구    126    153     13     14      8      7    618   1434   2348   2649
# 관악구    343    471     20     18     12     12   1715   4273   4418   5352
# 광진구    220    240     26     14      4      4   1277   3026   2180   2625
#
#          강간검거율       강도검거율       살인검거율      절도검거율      폭력검거율
# 구역
# 강남구  77.728285   85.714286   76.923077  42.857143  86.484594
# 강동구  78.846154  133.333333   75.000000  33.347422  82.890855
# 강북구  82.352941   92.857143  114.285714  43.096234  88.637222
# 관악구  72.823779  111.111111  100.000000  40.135736  82.548580
# 광진구  91.666667  185.714286  100.000000  42.200925  83.047619

# %%
crime_anal.drop(['강간 검거','강도 검거','절도 검거','폭력 검거','살인 검거'], axis = 1, inplace=True)
crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율       살인검거율  \
# 구역
# 강남구    449     21     13   3850   4284  77.728285   85.714286   76.923077
# 강동구    156      6      4   2366   2712  78.846154  133.333333   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  114.285714
# 관악구    471     18     12   4273   5352  72.823779  111.111111  100.000000
# 광진구    240     14      4   3026   2625  91.666667  185.714286  100.000000
#
#          절도검거율      폭력검거율
# 구역
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 관악구  40.135736  82.548580
# 광진구  42.200925  83.047619

# %%
col_list = '강간검거율	강도검거율	살인검거율	절도검거율	폭력검거율'.split('	')

# %%
for col in col_list:
    crime_anal.loc[crime_anal[col]>100,col] = 100

# %%
crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율       살인검거율  \
# 구역
# 강남구    449     21     13   3850   4284  77.728285   85.714286   76.923077
# 강동구    156      6      4   2366   2712  78.846154  100.000000   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  100.000000
# 관악구    471     18     12   4273   5352  72.823779  100.000000  100.000000
# 광진구    240     14      4   3026   2625  91.666667  100.000000  100.000000
#
#          절도검거율      폭력검거율
# 구역
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 관악구  40.135736  82.548580
# 광진구  42.200925  83.047619

# %%
crime_anal.rename(columns = {'강간 발생':'강간',
                             '살인 발생':'살인',
                             '절도 발생':'절도',
                             '폭력 발생':'폭력',
                             '강도 발생':'강도'},
                 inplace = True)

# %%
crime_anal
# Out:
#        강간  강도  살인    절도    폭력       강간검거율       강도검거율       살인검거율      절도검거율  \
# 구역
# 강남구   449  21  13  3850  4284   77.728285   85.714286   76.923077  42.857143
# 강동구   156   6   4  2366  2712   78.846154  100.000000   75.000000  33.347422
# 강북구   153  14   7  1434  2649   82.352941   92.857143  100.000000  43.096234
# 관악구   471  18  12  4273  5352   72.823779  100.000000  100.000000  40.135736
# 광진구   240  14   4  3026  2625   91.666667  100.000000  100.000000  42.200925
# 구로구   281  15   8  2335  3007   58.362989   73.333333   75.000000  38.072805
# 노원구   197   7  10  2193  2723   61.421320  100.000000  100.000000  36.525308
# 도봉구   102   9   3  1063  1487  100.000000  100.000000  100.000000  44.967074
# 동대문구  173  13   5  1981  2548   84.393064  100.000000  100.000000  41.090358
# 동작구   285   9   5  1865  1910   48.771930   55.555556  100.000000  35.442359
# 마포구   294  14   8  2555  2983   84.013605   71.428571  100.000000  31.819961
# ...

# %% [markdown]
# # 정규화 테스트, 지움 !

# %%
from sklearn import preprocessing

# %%
X = crime_anal[['살인']].copy()
X.drop('서대문구', inplace= True)

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scaled = min_max_scaler.fit_transform(X.astype(float))
X_scaled
# Out:
# array([[0.90909091],
#        [0.09090909],
#        [0.36363636],
#        [0.81818182],
#        [0.09090909],
#        [0.45454545],
#        [0.63636364],
#        [0.        ],
#        [0.18181818],
#        [0.18181818],
#        [0.45454545],
#        [0.45454545],
#        [0.09090909],
#        [0.18181818],
#        [0.72727273],
#        [0.63636364],
#        [1.        ],
#        [0.18181818],
#        [0.        ],
#        [0.27272727],
#        [0.        ],
#        [0.90909091]])

# %%
X["N"] = X_scaled

# %%
X.sort_values(by="살인")
# Out:
#       살인         N
# 구역
# 은평구    3  0.000000
# 중구     3  0.000000
# 도봉구    3  0.000000
# 강동구    4  0.090909
# 성동구    4  0.090909
# 광진구    4  0.090909
# 성북구    5  0.181818
# 용산구    5  0.181818
# 동작구    5  0.181818
# 동대문구   5  0.181818
# 종로구    6  0.272727
# 강북구    7  0.363636
# 구로구    8  0.454545
# 서초구    8  0.454545
# 마포구    8  0.454545
# 노원구   10  0.636364
# 양천구   10  0.636364
# 송파구   11  0.727273
# 관악구   12  0.818182
# 강남구   13  0.909091
# 중랑구   13  0.909091
# 영등포구  14  1.000000

# %%
Y = X.copy()

# %%
Y.sort_values(by = '살인')
# Out:
#       살인         N
# 구역
# 은평구    3  0.000000
# 중구     3  0.000000
# 도봉구    3  0.000000
# 강동구    4  0.090909
# 성동구    4  0.090909
# 광진구    4  0.090909
# 성북구    5  0.181818
# 용산구    5  0.181818
# 동작구    5  0.181818
# 동대문구   5  0.181818
# 종로구    6  0.272727
# 강북구    7  0.363636
# 구로구    8  0.454545
# 서초구    8  0.454545
# 마포구    8  0.454545
# 노원구   10  0.636364
# 양천구   10  0.636364
# 송파구   11  0.727273
# 관악구   12  0.818182
# 강남구   13  0.909091
# 중랑구   13  0.909091
# 영등포구  14  1.000000
